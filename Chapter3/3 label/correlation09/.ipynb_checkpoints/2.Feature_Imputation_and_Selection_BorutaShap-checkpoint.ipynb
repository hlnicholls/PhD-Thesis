# %% [markdown]
# ## Feature Imputation and BorutaShap Feature Selection
# - Feature imputation by random forest, followed by model score testing (ran from scoring folder)
# - Best model training data scores then used when running BorutaShap feature selection

# %%
import re

import numpy as np
import pandas as pd
from numpy import sort
from scipy.cluster import hierarchy
from scipy.stats import spearmanr

regex = re.compile(r"\[|\]|<", re.IGNORECASE)

import seaborn as sns
import shap
import statsmodels.api as sm
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base

# %matplotlib inline
# %config InlineBackend.figure_format ='retina'
import statsmodels.stats.api as sms
import xgboost
from BorutaShap import BorutaShap
from missingpy import MissForest
from sklearn.ensemble import (
    BaggingRegressor,
    ExtraTreesRegressor,
    GradientBoostingRegressor,
    RandomForestRegressor,
    StackingRegressor,
    VotingRegressor,
)

sns.set_style("darkgrid")
sns.mpl.rcParams["figure.figsize"] = (15.0, 9.0)

import warnings

import matplotlib
import matplotlib.pyplot as plt

warnings.simplefilter(action="ignore", category=FutureWarning)
from warnings import filterwarnings

filterwarnings("ignore")

seed = 0

# %%
data = pd.read_csv("2021-11-19_training_cleaned.csv", header=0, sep=",")

# %%
data["BPlabel_encoded"] = data["BPlabel"].map(
    {"most likely": 1, "probable": 2, "least likely": 3}
)
Y = data["BPlabel_encoded"]
data = data.drop(["BPlabel"], 1)
data.shape
# Out:
# (243, 103)

# %% [markdown]
# ### MissForest Imputation:

# %%
df1 = data.iloc[:, 0:102]
df = df1.set_index("Gene")

# %%
imputer = MissForest(random_state=seed)
X = pd.DataFrame(imputer.fit_transform(df), index=df.index, columns=df.columns)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4

# %%
X.to_csv(r"2021-11-19_imputed_training_data.csv", index=False)

# %% [markdown]
# ### BorutaShap Feature Selection:

# %%
# Best model and parameters measured on performance with all features to be used in BorutaShap

xgbr = xgboost.XGBClassifier(
    n_estimators=50,
    learning_rate= 0.01,
    max_depth=3,
    reg_alpha=3,
    reg_lambda=1,
    random_state=seed,
    eval_metric='mlogloss'
)

Feature_Selector = BorutaShap(
    model=xgbr, importance_measure="shap", classification=True
)

Feature_Selector.fit(X=X, y=Y, n_trials=100, random_state=seed)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 8 attributes confirmed important: ['pLI_ExAC', 'IPA_BP_annotation', 'HIPred', 'Pituitary_GTExFC', 'Colon_Sigmoid_GTExFC', 'ExomiserScore', 'Brain_Cortex_GTExFC', 'Artery_Coronary_GTExFC']
# 93 attributes confirmed unimportant: ['Brain_Cerebellum_GTExFC', 'Brain - Cerebellar Hemisphere_GTExTPM', 'Esophagus - Muscularis_GTExTPM', 'Adipose - Visceral (Omentum)_GTExTPM', 'Prostate_GTExFC', 'Artery - Tibial_GTExTPM', 'Brain - Caudate (basal ganglia)_GTExTPM', 'Adrenal_Gland_GTExFC', 'Stomach_GTExFC', '`Brain_Spinal_cord_cervical_c-1`_GTExFC', 'Skin - Not Sun Exposed (Suprapubic)_GTExTPM', 'Stomach_GTExTPM', 'Lung_GTExTPM', 'IPA_Activity', 'Brain_Putamen_basal_ganglia_GTExFC', 'Brain_Amygdala_GTExFC', 'Cells - EBV-transformed lymphocytes_GTExTPM', 'Thyroid_GTExTPM', 'Brain - Cortex_GTExTPM', 'Brain - Hippocampus_GTExTPM', 'Minor Salivary Gland_GTExTPM', 'Brain_Cerebellar_Hemisphere_GTExFC', 'Adipose_Subcutaneous_GTExFC', 'Kidney - Medulla_GTExTPM', 'Minor_Salivary_Gland_GTExFC', 'Nerve - Tibial_GTExTPM', 'Artery - Aorta_GTExTPM', 'Pancreas_GTExFC', 'Adrenal Gland_GTExTPM', 'Brain - Spinal cord (cervical c-1)_GTExTPM', 'Spleen_GTExTPM', 'Kidney - Cortex_GTExTPM', 'Heart_Atrial_Appendage_GTExFC', 'Lung_GTExFC', 'Brain - Frontal Cortex (BA9)_GTExTPM', 'wgEncodeBroadHmmHuvecHMM.count', 'Brain_Nucleus_accumbens_basal_ganglia_GTExFC', 'Esophagus_Gastroesophageal_Junction_GTExFC', 'Heart_Left_Ventricle_GTExFC', 'Heart - Atrial Appendage_GTExTPM', 'Spleen_GTExFC', 'Uterus_GTExFC', 'Brain - Hypothalamus_GTExTPM', 'Vagina_GTExFC', 'Brain - Amygdala_GTExTPM', 'Pituitary_GTExTPM', 'GDI_Score', 'Nerve_Tibial_GTExFC', 'Brain_Substantia_nigra_GTExFC', 'Skin_Sun_Exposed_Lower_leg_GTExFC', 'Brain_Caudate_basal_ganglia_GTExFC', 'Breast_Mammary_Tissue_GTExFC', 'Liver_GTExTPM', 'Cervix - Ectocervix_GTExTPM', 'Brain_Frontal_Cortex_BA9_GTExFC', 'Colon_Transverse_GTExFC', 'Small Intestine - Terminal Ileum_GTExTPM', 'Brain - Cerebellum_GTExTPM', 'Muscle - Skeletal_GTExTPM', 'SDI', 'logpval_gwascatalog', 'Brain_Hippocampus_GTExFC', 'Whole Blood_GTExTPM', 'Brain_Anterior_cingulate_cortex_BA24_GTExFC', 'Thyroid_GTExFC', 'Brain - Anterior cingulate cortex (BA24)_GTExTPM', 'betamax', 'Artery_Aorta_GTExFC', 'Colon - Transverse_GTExTPM', 'Esophagus_Muscularis_GTExFC', 'Prostate_GTExTPM', 'Artery_Tibial_GTExFC', 'Vagina_GTExTPM', 'Fallopian Tube_GTExTPM', 'Brain_Hypothalamus_GTExFC', 'Adipose - Subcutaneous_GTExTPM', 'Kidney_Cortex_GTExFC', 'Testis_GTExFC', 'Uterus_GTExTPM', 'Skin_Not_Sun_Exposed_Suprapubic_GTExFC', 'Liver_GTExFC', 'Cells_Cultured_fibroblasts_GTExFC', 'Adipose_Visceral_Omentum_GTExFC', 'Ovary_GTExFC', 'Cervix - Endocervix_GTExTPM', 'Esophagus_Mucosa_GTExFC', 'Small_Intestine_Terminal_Ileum_GTExFC', 'Esophagus - Mucosa_GTExTPM', 'Cells - Cultured fibroblasts_GTExTPM', 'Testis_GTExTPM', 'Pancreas_GTExTPM', 'Brain - Substantia nigra_GTExTPM', 'Ovary_GTExTPM']
# 0 tentative attributes remains: []

# %%
Feature_Selector.TentativeRoughFix()
# Out:
# 0 tentative features are now accepted: []
# 0 tentative features are now rejected: []

# %%
Feature_Selector.plot(which_features="all", X_rotation=90, figsize=(18,8))

# %%
Feature_Selector.plot(which_features="accepted")

# %%
subset = Feature_Selector.Subset()

# Selected features:
X_boruta_sel = subset

X_boruta_sel.shape
# Out:
# (243, 8)

# %%
X_boruta_sel
# Out:
#             pLI_ExAC  IPA_BP_annotation    HIPred  Pituitary_GTExFC  \
# Gene
# ABCC9       0.000701                1.0  0.670620          0.568715
# AC020983.5  0.124689                0.0  0.273180          0.258461
# AC093677.1  0.609972                0.0  0.675199          0.003405
# AC097374.4  0.939987                0.0  0.740533          0.014148
# AC103563.2  0.105048                0.0  0.283038         -0.590087
# ...              ...                ...       ...               ...
# VAMP2       0.837118                0.0  0.598058          0.128110
# VDR         0.392125                1.0  0.786469         -1.157770
# VEGFA       0.405673                1.0  0.676021         -0.636555
# YES1        0.046392                0.0  0.745583          0.101010
# ZAP70       0.272667                0.0  0.792615         -0.484126
#
#             Colon_Sigmoid_GTExFC  ExomiserScore  Brain_Cortex_GTExFC  \
# Gene
# ABCC9                   0.667657       0.884429             0.250539
# AC020983.5             -2.212181       0.130339            -0.852538
# AC093677.1             -0.056610       0.455213            -0.027565
# AC097374.4             -0.075436       0.477059            -0.019800
# AC103563.2             -2.549860       0.112987            -1.080460
# ...                          ...            ...                  ...
# VAMP2                   0.071066       0.501797            -0.156217
# VDR                    -0.541575       0.959359            -0.487937
# VEGFA                  -1.062173       0.528332             1.749947
# YES1                    0.116800       0.506090             0.155665
# ZAP70                  -0.343206       0.526725            -0.646464
#
#             Artery_Coronary_GTExFC
# Gene
# ABCC9                     0.429516
# AC020983.5               -0.628662
# AC093677.1                0.003460
# AC097374.4               -0.001928
# AC103563.2               -1.538959
# ...                            ...
# VAMP2                    -0.120251
# VDR                       1.536193
# VEGFA                     0.558394
# YES1                      0.098462
# ZAP70                     1.353324
#
# [243 rows x 8 columns]

# %%
X_boruta_sel.to_csv(r"2021-11-19_selected_features_training_data.csv", index=False)
