# %% [markdown]
# ## Feature Imputation and BorutaShap Feature Selection
# - Feature imputation by random forest, followed by model score testing (ran from scoring folder)
# - Best model training data scores then used when running BorutaShap feature selection

# %%
import re

import numpy as np
import pandas as pd
from numpy import sort
from scipy.cluster import hierarchy
from scipy.stats import spearmanr

regex = re.compile(r"\[|\]|<", re.IGNORECASE)

import seaborn as sns
import shap
import statsmodels.api as sm
import sys
import sklearn.neighbors._base
sys.modules['sklearn.neighbors.base'] = sklearn.neighbors._base

# %matplotlib inline
# %config InlineBackend.figure_format ='retina'
import statsmodels.stats.api as sms
import xgboost
from BorutaShap import BorutaShap
from missingpy import MissForest
from sklearn.ensemble import (
    BaggingRegressor,
    ExtraTreesRegressor,
    GradientBoostingRegressor,
    RandomForestRegressor,
    StackingRegressor,
    VotingRegressor,
)

sns.set_style("darkgrid")
sns.mpl.rcParams["figure.figsize"] = (15.0, 9.0)

import warnings

import matplotlib
import matplotlib.pyplot as plt

warnings.simplefilter(action="ignore", category=FutureWarning)
from warnings import filterwarnings

filterwarnings("ignore")

seed = 0

# %%
data = pd.read_csv("2021-11-19_training_cleaned.csv", header=0, sep=",")

# %%
data["BPlabel_encoded"] = data["BPlabel"].map(
    {"most likely": 1, "probable": 2,  "possible": 3, "least likely": 4}
)
Y = data["BPlabel_encoded"]
data = data.drop(["BPlabel"], 1)
data.shape
# Out:
# (327, 109)

# %% [markdown]
# ### MissForest Imputation:

# %%
df1 = data.iloc[:, 0:108]
df = df1.set_index("Gene")

# %%
imputer = MissForest(random_state=seed)
X = pd.DataFrame(imputer.fit_transform(df), index=df.index, columns=df.columns)
# Out:
# Iteration: 0
# Iteration: 1
# Iteration: 2
# Iteration: 3
# Iteration: 4
# Iteration: 5

# %%
X.to_csv(r"2021-11-19_imputed_training_data.csv", index=False)

# %% [markdown]
# ### BorutaShap Feature Selection:

# %%
# Best model and parameters measured on performance with all features to be used in BorutaShap

xgbr = xgboost.XGBClassifier(
    n_estimators=50,
    learning_rate= 0.01,
    max_depth=3,
    reg_alpha=1,
    reg_lambda=5,
    random_state=seed,
    eval_metric='mlogloss'
)

Feature_Selector = BorutaShap(
    model=xgbr, importance_measure="shap", classification=True
)

Feature_Selector.fit(X=X, y=Y, n_trials=100, random_state=seed)
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# 6 attributes confirmed important: ['ExomiserScore', 'Brain - Spinal cord (cervical c-1)_GTExTPM', 'Artery_Coronary_GTExFC', 'Brain_Cerebellum_GTExFC', 'DeepSEA_Functional_Significance', 'Artery - Tibial_GTExTPM']
# 101 attributes confirmed unimportant: ['Small_Intestine_Terminal_Ileum_GTExFC', '`Brain_Spinal_cord_cervical_c-1`_GTExFC', 'Pituitary_GTExFC', 'Brain_Hypothalamus_GTExFC', 'Breast_Mammary_Tissue_GTExFC', 'Vagina_GTExFC', 'betamax', 'Colon - Sigmoid_GTExTPM', 'Cervix - Endocervix_GTExTPM', 'SignalValue_H3k4me3_median', 'Testis_GTExFC', 'SDI', 'Cells - Cultured fibroblasts_GTExTPM', 'Esophagus_Mucosa_GTExFC', 'Ovary_GTExFC', 'Brain - Hypothalamus_GTExTPM', 'Lung_GTExFC', 'Adrenal Gland_GTExTPM', 'Brain - Hippocampus_GTExTPM', 'Whole Blood_GTExTPM', 'Adipose - Visceral (Omentum)_GTExTPM', 'Stomach_GTExFC', 'Heart - Atrial Appendage_GTExTPM', 'logpval_gwascatalog', 'Prostate_GTExFC', 'Brain_Nucleus_accumbens_basal_ganglia_GTExFC', 'Skin_Not_Sun_Exposed_Suprapubic_GTExFC', 'Artery_Tibial_GTExFC', 'Uterus_GTExTPM', 'Bladder_GTExTPM', 'Esophagus_Muscularis_GTExFC', 'Heart_Atrial_Appendage_GTExFC', 'Brain - Substantia nigra_GTExTPM', 'Minor Salivary Gland_GTExTPM', 'Brain_Frontal_Cortex_BA9_GTExFC', 'Minor_Salivary_Gland_GTExFC', 'Vagina_GTExTPM', 'Brain - Amygdala_GTExTPM', 'CNVs_ExAC', 'Skin - Not Sun Exposed (Suprapubic)_GTExTPM', 'Esophagus - Mucosa_GTExTPM', 'Pancreas_GTExTPM', 'Brain - Caudate (basal ganglia)_GTExTPM', 'Brain_Cortex_GTExFC', 'Pituitary_GTExTPM', 'Brain - Cortex_GTExTPM', 'Brain_Caudate_basal_ganglia_GTExFC', 'Adrenal_Gland_GTExFC', 'pLI_ExAC', 'Colon_Sigmoid_GTExFC', 'Adipose_Subcutaneous_GTExFC', 'Thyroid_GTExFC', 'Esophagus_Gastroesophageal_Junction_GTExFC', '`Cells_EBV-transformed_lymphocytes`_GTExFC', 'Artery - Aorta_GTExTPM', 'Lung_GTExTPM', 'Stomach_GTExTPM', 'Brain - Cerebellar Hemisphere_GTExTPM', 'Artery_Aorta_GTExFC', 'Cervix - Ectocervix_GTExTPM', 'Nerve_Tibial_GTExFC', 'Uterus_GTExFC', 'wgEncodeBroadHmmHuvecHMM.count', 'Liver_GTExFC', 'Muscle - Skeletal_GTExTPM', 'Brain_Anterior_cingulate_cortex_BA24_GTExFC', 'RVIS_Score', 'Cells_Cultured_fibroblasts_GTExFC', 'Liver_GTExTPM', 'Brain_Hippocampus_GTExFC', 'Kidney - Medulla_GTExTPM', 'Colon_Transverse_GTExFC', 'Brain - Anterior cingulate cortex (BA24)_GTExTPM', 'Cells - EBV-transformed lymphocytes_GTExTPM', 'GDI_Score', 'Colon - Transverse_GTExTPM', 'Heart_Left_Ventricle_GTExFC', 'Thyroid_GTExTPM', 'Brain_Substantia_nigra_GTExFC', 'Esophagus - Muscularis_GTExTPM', 'Spleen_GTExTPM', 'Adipose - Subcutaneous_GTExTPM', 'Artery - Coronary_GTExTPM', 'Prostate_GTExTPM', 'Nerve - Tibial_GTExTPM', 'Ovary_GTExTPM', 'Fallopian Tube_GTExTPM', 'Kidney - Cortex_GTExTPM', 'Brain_Putamen_basal_ganglia_GTExFC', 'Testis_GTExTPM', 'Small Intestine - Terminal Ileum_GTExTPM', 'Kidney_Cortex_GTExFC', 'Adipose_Visceral_Omentum_GTExFC', 'Muscle_Skeletal_GTExFC', 'HIPred', 'Skin_Sun_Exposed_Lower_leg_GTExFC', 'Pancreas_GTExFC', 'Spleen_GTExFC', 'SignalValue_H3k4me1_median', 'Brain_Cerebellar_Hemisphere_GTExFC', 'Brain_Amygdala_GTExFC']
# 0 tentative attributes remains: []

# %%
Feature_Selector.TentativeRoughFix()
# Out:
# 0 tentative features are now accepted: []
# 0 tentative features are now rejected: []

# %%
Feature_Selector.plot(which_features="all", X_rotation=90, figsize=(18,8))

# %%
Feature_Selector.plot(which_features="accepted")

# %%
subset = Feature_Selector.Subset()

# Selected features:
X_boruta_sel = subset

X_boruta_sel.shape
# Out:
# (327, 6)

# %%
X_boruta_sel
# Out:
#             ExomiserScore  Brain - Spinal cord (cervical c-1)_GTExTPM  \
# Gene
# ABCC8            0.537333                                    9.749420
# ABCC9            0.884429                                    1.015900
# AC020983.5       0.171165                                    0.000000
# AC093677.1       0.386632                                   30.898641
# AC097374.4       0.428291                                   31.997845
# ...                   ...                                         ...
# VEGFA            0.528332                                   16.422000
# YES1             0.506090                                   18.009400
# ZAP70            0.526725                                    1.730130
# ZNF516           0.000000                                    2.086580
# ZNF827           0.000000                                    4.257770
#
#             Artery_Coronary_GTExFC  Brain_Cerebellum_GTExFC  \
# Gene
# ABCC8                     3.160413                 0.302197
# ABCC9                     0.429516                -1.363194
# AC020983.5               -2.842554                -0.414838
# AC093677.1               -0.050814                 0.046958
# AC097374.4               -0.037399                 0.048430
# ...                            ...                      ...
# VEGFA                     0.558394                -0.880271
# YES1                      0.098462                -0.172090
# ZAP70                     1.353324                -1.811005
# ZNF516                   -1.404978                 0.564006
# ZNF827                    0.776371                 0.081332
#
#             DeepSEA_Functional_Significance  Artery - Tibial_GTExTPM
# Gene
# ABCC8                              0.006330                 0.189693
# ABCC9                              0.079261                12.814100
# AC020983.5                         0.082156                 0.000000
# AC093677.1                         0.090293               172.774381
# AC097374.4                         0.044808               165.774631
# ...                                     ...                      ...
# VEGFA                              0.074601                50.741100
# YES1                               0.134070                17.429400
# ZAP70                              0.157360                 0.957474
# ZNF516                             0.061035                 4.212820
# ZNF827                             0.002448                11.145000
#
# [327 rows x 6 columns]

# %%
X_boruta_sel.to_csv(r"2021-11-19_selected_features_training_data.csv", index=False)
