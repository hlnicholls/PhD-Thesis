# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob
files = glob.glob("path/*.csv")


import gc
import itertools
from copy import deepcopy

from tqdm import tqdm

from scipy.stats import ks_2samp

from sklearn.preprocessing import scale, MinMaxScaler
from sklearn.manifold import TSNE
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import FastICA
from sklearn.decomposition import PCA
from sklearn.random_projection import GaussianRandomProjection
from sklearn.random_projection import SparseRandomProjection

from sklearn import manifold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report
from sklearn.model_selection import StratifiedKFold

import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
# %matplotlib inline

# %%
train_folds = {}
for filename in glob.glob('*.csv'):
    if "train" in filename:
        train_folds[filename[:-4]] = pd.read_csv(filename)

# %%
test_folds = {}
for filename in glob.glob('*.csv'):
    if "val" in filename:
        test_folds[filename[:-4]] = pd.read_csv(filename)

# %%
train1 = pd.DataFrame.from_dict(train_folds['train_fold_1'])
train2 = pd.DataFrame.from_dict(train_folds['train_fold_2'])
train3 = pd.DataFrame.from_dict(train_folds['train_fold_3'])
train4 = pd.DataFrame.from_dict(train_folds['train_fold_4'])
train5 = pd.DataFrame.from_dict(train_folds['train_fold_5'])
train6 = pd.DataFrame.from_dict(train_folds['train_fold_6'])
train7 = pd.DataFrame.from_dict(train_folds['train_fold_7'])
train8 = pd.DataFrame.from_dict(train_folds['train_fold_8'])
train9 = pd.DataFrame.from_dict(train_folds['train_fold_9'])
train10 = pd.DataFrame.from_dict(train_folds['train_fold_10'])

# %%
test1 = pd.DataFrame.from_dict(test_folds['val_fold_1'])
test2 = pd.DataFrame.from_dict(test_folds['val_fold_2'])
test3 = pd.DataFrame.from_dict(test_folds['val_fold_3'])
test4 = pd.DataFrame.from_dict(test_folds['val_fold_4'])
test5 = pd.DataFrame.from_dict(test_folds['val_fold_5'])
test6 = pd.DataFrame.from_dict(test_folds['val_fold_6'])
test7 = pd.DataFrame.from_dict(test_folds['val_fold_7'])
test8 = pd.DataFrame.from_dict(test_folds['val_fold_8'])
test9 = pd.DataFrame.from_dict(test_folds['val_fold_9'])
test10 = pd.DataFrame.from_dict(test_folds['val_fold_10'])

# %%
groupDF = [train1,train2,train3,train4,train5,train6,train7,train8,train9,train10,test1,test2,test3,test4,test5,test6,test7,test8,test9,test10
]
for i in groupDF:
    i.drop(i.columns[[0,21]], axis=1, inplace=True)

# %%
# Find the columns where the distributions are very different
threshold=0.1
diff_data1 = []
for col in tqdm(train1.columns):
    statistic, pvalue = ks_2samp(
        train1[col].values, 
        test1[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data1.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data1.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df1 = pd.DataFrame(diff_data1).sort_values(by='statistic', ascending=False)

diff_df1
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 473.65it/s]
#                                          feature                  statistic
# 0                 wgEncodeBroadHmmHuvecHMM.count  No significant difference
# 1                                      GDI_Score  No significant difference
# 26                           Brain_Cortex_GTExFC  No significant difference
# 27                     Brain_Hypothalamus_GTExFC  No significant difference
# 28  Brain_Nucleus_accumbens_basal_ganglia_GTExFC  No significant difference
# 29                       Colon_Transverse_GTExFC  No significant difference
# 30        Skin_Not_Sun_Exposed_Suprapubic_GTExFC  No significant difference
# 31            Brain_Caudate_basal_ganglia_GTExFC  No significant difference
# 32       `Brain_Spinal_cord_cervical_c-1`_GTExFC  No significant difference
# 33   Brain_Anterior_cingulate_cortex_BA24_GTExFC  No significant difference
# 34             Skin_Sun_Exposed_Lower_leg_GTExFC  No significant difference
# 35                       Brain_Cerebellum_GTExFC  No significant difference
# 36                           Nerve_Tibial_GTExFC  No significant difference
# 37                  Breast_Mammary_Tissue_GTExFC  No significant difference
# 38                      Brain_Hippocampus_GTExFC  No significant difference
# 39            Brain_Cerebellar_Hemisphere_GTExFC  No significant difference
# 40                 Brain_Substantia_nigra_GTExFC  No significant difference
# 41                          Colon_Sigmoid_GTExFC  No significant difference
# 42                                  Ovary_GTExFC  No significant difference
# 43                                Stomach_GTExFC  No significant difference
# 44                                   Lung_GTExFC  No significant difference
# 45                        Artery_Coronary_GTExFC  No significant difference
# 46            Brain_Putamen_basal_ganglia_GTExFC  No significant difference
# 25               Brain_Frontal_Cortex_BA9_GTExFC  No significant difference
# 24                               Prostate_GTExFC  No significant difference
# 23                                    RVIS_Score  No significant difference
# 11                      Brain - Amygdala_GTExTPM  No significant difference
# 2                                        betamax  No significant difference
# 3                      Muscle - Skeletal_GTExTPM  No significant difference
# 4                   Minor Salivary Gland_GTExTPM  No significant difference
# 5                                  Liver_GTExTPM  No significant difference
# 6                       Kidney - Medulla_GTExTPM  No significant difference
# 7                              Pituitary_GTExTPM  No significant difference
# 8                                 Testis_GTExTPM  No significant difference
# 9                               Pancreas_GTExTPM  No significant difference
# 10                         Adrenal Gland_GTExTPM  No significant difference
# 12          Cells - Cultured fibroblasts_GTExTPM  No significant difference
# 22         Small_Intestine_Terminal_Ileum_GTExFC  No significant difference
# 13   Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 14                           mousescore_Exomiser  No significant difference
# 15                            fishscore_Exomiser  No significant difference
# 16                           humanscore_Exomiser  No significant difference
# 17                                        HIPred  No significant difference
# 18                                      pLI_ExAC  No significant difference
# 19                                           SDI  No significant difference
# 20                    SignalValue_H3k4me1_median  No significant difference
# 21                              Pituitary_GTExFC  No significant difference
# 47                               BPlabel_encoded  No significant difference

# %%
threshold=0.1
diff_data2 = []
for col in tqdm(train1.columns):
    statistic, pvalue = ks_2samp(
        train2[col].values, 
        test2[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data2.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})

# Put the differences into a dataframe
diff_df2 = pd.DataFrame(diff_data2).sort_values(by='statistic', ascending=False)

diff_df2
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 470.05it/s]
#                                  feature        p  statistic
# 0                  Adrenal Gland_GTExTPM  0.00346       0.30
# 2     Brain_Caudate_basal_ganglia_GTExFC  0.00293       0.30
# 1  Small_Intestine_Terminal_Ileum_GTExFC  0.00848       0.28
# 3                   Colon_Sigmoid_GTExFC  0.00797       0.28

# %%
threshold=0.1
diff_data3 = []
for col in tqdm(train3.columns):
    statistic, pvalue = ks_2samp(
        train3[col].values, 
        test3[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data3.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data3.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df3 = pd.DataFrame(diff_data3).sort_values(by='statistic', ascending=False)

diff_df3
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 440.32it/s]
#                                          feature                  statistic
# 0                 wgEncodeBroadHmmHuvecHMM.count  No significant difference
# 1                                      GDI_Score  No significant difference
# 26                           Brain_Cortex_GTExFC  No significant difference
# 27                     Brain_Hypothalamus_GTExFC  No significant difference
# 28  Brain_Nucleus_accumbens_basal_ganglia_GTExFC  No significant difference
# 29                       Colon_Transverse_GTExFC  No significant difference
# 30        Skin_Not_Sun_Exposed_Suprapubic_GTExFC  No significant difference
# 31            Brain_Caudate_basal_ganglia_GTExFC  No significant difference
# 32       `Brain_Spinal_cord_cervical_c-1`_GTExFC  No significant difference
# 33   Brain_Anterior_cingulate_cortex_BA24_GTExFC  No significant difference
# 34             Skin_Sun_Exposed_Lower_leg_GTExFC  No significant difference
# 35                       Brain_Cerebellum_GTExFC  No significant difference
# 36                           Nerve_Tibial_GTExFC  No significant difference
# 37                  Breast_Mammary_Tissue_GTExFC  No significant difference
# 38                      Brain_Hippocampus_GTExFC  No significant difference
# 39            Brain_Cerebellar_Hemisphere_GTExFC  No significant difference
# 40                 Brain_Substantia_nigra_GTExFC  No significant difference
# 41                          Colon_Sigmoid_GTExFC  No significant difference
# 42                                  Ovary_GTExFC  No significant difference
# 43                                Stomach_GTExFC  No significant difference
# 44                                   Lung_GTExFC  No significant difference
# 45                        Artery_Coronary_GTExFC  No significant difference
# 46            Brain_Putamen_basal_ganglia_GTExFC  No significant difference
# 25               Brain_Frontal_Cortex_BA9_GTExFC  No significant difference
# 24                               Prostate_GTExFC  No significant difference
# 23                                    RVIS_Score  No significant difference
# 11                      Brain - Amygdala_GTExTPM  No significant difference
# 2                                        betamax  No significant difference
# 3                      Muscle - Skeletal_GTExTPM  No significant difference
# 4                   Minor Salivary Gland_GTExTPM  No significant difference
# 5                                  Liver_GTExTPM  No significant difference
# 6                       Kidney - Medulla_GTExTPM  No significant difference
# 7                              Pituitary_GTExTPM  No significant difference
# 8                                 Testis_GTExTPM  No significant difference
# 9                               Pancreas_GTExTPM  No significant difference
# 10                         Adrenal Gland_GTExTPM  No significant difference
# 12          Cells - Cultured fibroblasts_GTExTPM  No significant difference
# 22         Small_Intestine_Terminal_Ileum_GTExFC  No significant difference
# 13   Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 14                           mousescore_Exomiser  No significant difference
# 15                            fishscore_Exomiser  No significant difference
# 16                           humanscore_Exomiser  No significant difference
# 17                                        HIPred  No significant difference
# 18                                      pLI_ExAC  No significant difference
# 19                                           SDI  No significant difference
# 20                    SignalValue_H3k4me1_median  No significant difference
# 21                              Pituitary_GTExFC  No significant difference
# 47                               BPlabel_encoded  No significant difference

# %%
threshold=0.1
diff_data4 = []
nondiff_data4 = []
for col in tqdm(train4.columns):
    statistic, pvalue = ks_2samp(
        train4[col].values, 
        test4[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data4.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data4.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df4 = pd.DataFrame(diff_data4).sort_values(by='statistic', ascending=False)
diff_df4
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 489.60it/s]
#                                          feature                  statistic
# 0                 wgEncodeBroadHmmHuvecHMM.count  No significant difference
# 1                                      GDI_Score  No significant difference
# 26                           Brain_Cortex_GTExFC  No significant difference
# 27                     Brain_Hypothalamus_GTExFC  No significant difference
# 28  Brain_Nucleus_accumbens_basal_ganglia_GTExFC  No significant difference
# 29                       Colon_Transverse_GTExFC  No significant difference
# 30        Skin_Not_Sun_Exposed_Suprapubic_GTExFC  No significant difference
# 31            Brain_Caudate_basal_ganglia_GTExFC  No significant difference
# 32       `Brain_Spinal_cord_cervical_c-1`_GTExFC  No significant difference
# 33   Brain_Anterior_cingulate_cortex_BA24_GTExFC  No significant difference
# 34             Skin_Sun_Exposed_Lower_leg_GTExFC  No significant difference
# 35                       Brain_Cerebellum_GTExFC  No significant difference
# 36                           Nerve_Tibial_GTExFC  No significant difference
# 37                  Breast_Mammary_Tissue_GTExFC  No significant difference
# 38                      Brain_Hippocampus_GTExFC  No significant difference
# 39            Brain_Cerebellar_Hemisphere_GTExFC  No significant difference
# 40                 Brain_Substantia_nigra_GTExFC  No significant difference
# 41                          Colon_Sigmoid_GTExFC  No significant difference
# 42                                  Ovary_GTExFC  No significant difference
# 43                                Stomach_GTExFC  No significant difference
# 44                                   Lung_GTExFC  No significant difference
# 45                        Artery_Coronary_GTExFC  No significant difference
# 46            Brain_Putamen_basal_ganglia_GTExFC  No significant difference
# 25               Brain_Frontal_Cortex_BA9_GTExFC  No significant difference
# 24                               Prostate_GTExFC  No significant difference
# 23                                    RVIS_Score  No significant difference
# 11                      Brain - Amygdala_GTExTPM  No significant difference
# 2                                        betamax  No significant difference
# 3                      Muscle - Skeletal_GTExTPM  No significant difference
# 4                   Minor Salivary Gland_GTExTPM  No significant difference
# 5                                  Liver_GTExTPM  No significant difference
# 6                       Kidney - Medulla_GTExTPM  No significant difference
# 7                              Pituitary_GTExTPM  No significant difference
# 8                                 Testis_GTExTPM  No significant difference
# 9                               Pancreas_GTExTPM  No significant difference
# 10                         Adrenal Gland_GTExTPM  No significant difference
# 12          Cells - Cultured fibroblasts_GTExTPM  No significant difference
# 22         Small_Intestine_Terminal_Ileum_GTExFC  No significant difference
# 13   Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 14                           mousescore_Exomiser  No significant difference
# 15                            fishscore_Exomiser  No significant difference
# 16                           humanscore_Exomiser  No significant difference
# 17                                        HIPred  No significant difference
# 18                                      pLI_ExAC  No significant difference
# 19                                           SDI  No significant difference
# 20                    SignalValue_H3k4me1_median  No significant difference
# 21                              Pituitary_GTExFC  No significant difference
# 47                               BPlabel_encoded  No significant difference

# %%
threshold=0.1
diff_data5 = []
for col in tqdm(train5.columns):
    statistic, pvalue = ks_2samp(
        train5[col].values, 
        test5[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data5.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
   # else: 
   #     diff_data5.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df5 = pd.DataFrame(diff_data5).sort_values(by='statistic', ascending=False)

diff_df5
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 450.91it/s]
#     feature        p  statistic
# 0  pLI_ExAC  0.00155       0.32

# %%
threshold=0.1
diff_data6 = []
for col in tqdm(train5.columns):
    statistic, pvalue = ks_2samp(
        train6[col].values, 
        test6[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data6.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
   # else: 
   #     diff_data6.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df6 = pd.DataFrame(diff_data6).sort_values(by='statistic', ascending=False)

diff_df6
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 402.19it/s]
#                               feature        p  statistic
# 0                      Stomach_GTExFC  0.00396       0.29
# 1  Brain_Putamen_basal_ganglia_GTExFC  0.00803       0.28

# %%
threshold=0.1
diff_data7 = []
for col in tqdm(train7.columns):
    statistic, pvalue = ks_2samp(
        train7[col].values, 
        test7[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data7.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})

diff_df7 = pd.DataFrame(diff_data7).sort_values(by='statistic', ascending=False)

diff_df7
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 408.71it/s]
#                                   feature        p  statistic
# 4               Brain_Hypothalamus_GTExFC  0.00020       0.36
# 6                Brain_Hippocampus_GTExFC  0.00091       0.33
# 1   Small_Intestine_Terminal_Ileum_GTExFC  0.00143       0.32
# 5  Skin_Not_Sun_Exposed_Suprapubic_GTExFC  0.00263       0.30
# 7                             Lung_GTExFC  0.00279       0.30
# 3                     Brain_Cortex_GTExFC  0.00404       0.29
# 0               Muscle - Skeletal_GTExTPM  0.00696       0.28
# 2                         Prostate_GTExFC  0.00943       0.27

# %%
threshold=0.1
diff_data8 = []
for col in tqdm(train3.columns):
    statistic, pvalue = ks_2samp(
        train8[col].values, 
        test8[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data8.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data8.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df8 = pd.DataFrame(diff_data8).sort_values(by='statistic', ascending=False)

diff_df8
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 430.57it/s]
#                                          feature                  statistic
# 0                 wgEncodeBroadHmmHuvecHMM.count  No significant difference
# 1                                      GDI_Score  No significant difference
# 26                           Brain_Cortex_GTExFC  No significant difference
# 27                     Brain_Hypothalamus_GTExFC  No significant difference
# 28  Brain_Nucleus_accumbens_basal_ganglia_GTExFC  No significant difference
# 29                       Colon_Transverse_GTExFC  No significant difference
# 30        Skin_Not_Sun_Exposed_Suprapubic_GTExFC  No significant difference
# 31            Brain_Caudate_basal_ganglia_GTExFC  No significant difference
# 32       `Brain_Spinal_cord_cervical_c-1`_GTExFC  No significant difference
# 33   Brain_Anterior_cingulate_cortex_BA24_GTExFC  No significant difference
# 34             Skin_Sun_Exposed_Lower_leg_GTExFC  No significant difference
# 35                       Brain_Cerebellum_GTExFC  No significant difference
# 36                           Nerve_Tibial_GTExFC  No significant difference
# 37                  Breast_Mammary_Tissue_GTExFC  No significant difference
# 38                      Brain_Hippocampus_GTExFC  No significant difference
# 39            Brain_Cerebellar_Hemisphere_GTExFC  No significant difference
# 40                 Brain_Substantia_nigra_GTExFC  No significant difference
# 41                          Colon_Sigmoid_GTExFC  No significant difference
# 42                                  Ovary_GTExFC  No significant difference
# 43                                Stomach_GTExFC  No significant difference
# 44                                   Lung_GTExFC  No significant difference
# 45                        Artery_Coronary_GTExFC  No significant difference
# 46            Brain_Putamen_basal_ganglia_GTExFC  No significant difference
# 25               Brain_Frontal_Cortex_BA9_GTExFC  No significant difference
# 24                               Prostate_GTExFC  No significant difference
# 23                                    RVIS_Score  No significant difference
# 11                      Brain - Amygdala_GTExTPM  No significant difference
# 2                                        betamax  No significant difference
# 3                      Muscle - Skeletal_GTExTPM  No significant difference
# 4                   Minor Salivary Gland_GTExTPM  No significant difference
# 5                                  Liver_GTExTPM  No significant difference
# 6                       Kidney - Medulla_GTExTPM  No significant difference
# 7                              Pituitary_GTExTPM  No significant difference
# 8                                 Testis_GTExTPM  No significant difference
# 9                               Pancreas_GTExTPM  No significant difference
# 10                         Adrenal Gland_GTExTPM  No significant difference
# 12          Cells - Cultured fibroblasts_GTExTPM  No significant difference
# 22         Small_Intestine_Terminal_Ileum_GTExFC  No significant difference
# 13   Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 14                           mousescore_Exomiser  No significant difference
# 15                            fishscore_Exomiser  No significant difference
# 16                           humanscore_Exomiser  No significant difference
# 17                                        HIPred  No significant difference
# 18                                      pLI_ExAC  No significant difference
# 19                                           SDI  No significant difference
# 20                    SignalValue_H3k4me1_median  No significant difference
# 21                              Pituitary_GTExFC  No significant difference
# 47                               BPlabel_encoded  No significant difference

# %%
threshold=0.1
diff_data9 = []
for col in tqdm(train9.columns):
    statistic, pvalue = ks_2samp(
        train9[col].values, 
        test9[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data9.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})


# Put the differences into a dataframe
diff_df9 = pd.DataFrame(diff_data9).sort_values(by='statistic', ascending=False)

diff_df9
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 399.85it/s]
#    feature        p  statistic
# 0  betamax  0.00823       0.28

# %%
threshold=0.1
diff_data10 = []
for col in tqdm(train3.columns):
    statistic, pvalue = ks_2samp(
        train10[col].values, 
        test10[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data10.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
   # else: 
   #     diff_data10.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df10 = pd.DataFrame(diff_data10).sort_values(by='statistic', ascending=False)

diff_df10
# Out:
# 100%|██████████| 48/48 [00:00<00:00, 426.56it/s]
#                feature        p  statistic
# 0  Brain_Cortex_GTExFC  0.00725       0.28

# %%
frames = [ diff_df2,diff_df5,diff_df6,diff_df7,diff_df9,diff_df10]
result = pd.concat(frames)

# %%
result_df = result.drop_duplicates(subset=['feature'], keep='first')
list(result_df['feature'])
# Out:
# ['Adrenal Gland_GTExTPM',
#  'Brain_Caudate_basal_ganglia_GTExFC',
#  'Small_Intestine_Terminal_Ileum_GTExFC',
#  'Colon_Sigmoid_GTExFC',
#  'pLI_ExAC',
#  'Stomach_GTExFC',
#  'Brain_Putamen_basal_ganglia_GTExFC',
#  'Brain_Hypothalamus_GTExFC',
#  'Brain_Hippocampus_GTExFC',
#  'Skin_Not_Sun_Exposed_Suprapubic_GTExFC',
#  'Lung_GTExFC',
#  'Brain_Cortex_GTExFC',
#  'Muscle - Skeletal_GTExTPM',
#  'Prostate_GTExFC',
#  'betamax']

# %%
df = pd.read_csv('imputed_training_data.csv')
df = df.drop(['Adrenal Gland_GTExTPM',
 'Brain_Caudate_basal_ganglia_GTExFC',
 'Small_Intestine_Terminal_Ileum_GTExFC',
 'Colon_Sigmoid_GTExFC',
 'pLI_ExAC',
 'Stomach_GTExFC',
 'Brain_Putamen_basal_ganglia_GTExFC',
 'Brain_Hypothalamus_GTExFC',
 'Brain_Hippocampus_GTExFC',
 'Skin_Not_Sun_Exposed_Suprapubic_GTExFC',
 'Lung_GTExFC',
 'Brain_Cortex_GTExFC',
 'Muscle - Skeletal_GTExTPM',
 'Prostate_GTExFC',
 'betamax'], 1, errors='ignore')
df.to_csv('cleaned_imputed_training_data.csv')
