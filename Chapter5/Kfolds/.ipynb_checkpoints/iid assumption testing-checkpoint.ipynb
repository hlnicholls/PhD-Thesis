# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import glob
files = glob.glob("path/*.csv")


import gc
import itertools
from copy import deepcopy

from tqdm import tqdm

from scipy.stats import ks_2samp

from sklearn.preprocessing import scale, MinMaxScaler
from sklearn.manifold import TSNE
from sklearn.decomposition import TruncatedSVD
from sklearn.decomposition import FastICA
from sklearn.decomposition import PCA
from sklearn.random_projection import GaussianRandomProjection
from sklearn.random_projection import SparseRandomProjection

from sklearn import manifold
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import classification_report
from sklearn.model_selection import StratifiedKFold

import matplotlib.pyplot as plt
from matplotlib.ticker import NullFormatter
# %matplotlib inline

# %%
train_folds = {}
for filename in glob.glob('*.csv'):
    if "train" in filename:
        train_folds[filename[:-4]] = pd.read_csv(filename)

# %%
test_folds = {}
for filename in glob.glob('*.csv'):
    if "val" in filename:
        test_folds[filename[:-4]] = pd.read_csv(filename)

# %%
train1 = pd.DataFrame.from_dict(train_folds['train_fold_1'])
train2 = pd.DataFrame.from_dict(train_folds['train_fold_2'])
train3 = pd.DataFrame.from_dict(train_folds['train_fold_3'])
train4 = pd.DataFrame.from_dict(train_folds['train_fold_4'])
train5 = pd.DataFrame.from_dict(train_folds['train_fold_5'])
train6 = pd.DataFrame.from_dict(train_folds['train_fold_6'])
train7 = pd.DataFrame.from_dict(train_folds['train_fold_7'])
train8 = pd.DataFrame.from_dict(train_folds['train_fold_8'])
train9 = pd.DataFrame.from_dict(train_folds['train_fold_9'])
train10 = pd.DataFrame.from_dict(train_folds['train_fold_10'])
train11 = pd.DataFrame.from_dict(train_folds['train_fold_11'])
train12 = pd.DataFrame.from_dict(train_folds['train_fold_12'])
train13 = pd.DataFrame.from_dict(train_folds['train_fold_13'])
train14 = pd.DataFrame.from_dict(train_folds['train_fold_14'])
train15 = pd.DataFrame.from_dict(train_folds['train_fold_15'])

# %%
test1 = pd.DataFrame.from_dict(test_folds['val_fold_1'])
test2 = pd.DataFrame.from_dict(test_folds['val_fold_2'])
test3 = pd.DataFrame.from_dict(test_folds['val_fold_3'])
test4 = pd.DataFrame.from_dict(test_folds['val_fold_4'])
test5 = pd.DataFrame.from_dict(test_folds['val_fold_5'])
test6 = pd.DataFrame.from_dict(test_folds['val_fold_6'])
test7 = pd.DataFrame.from_dict(test_folds['val_fold_7'])
test8 = pd.DataFrame.from_dict(test_folds['val_fold_8'])
test9 = pd.DataFrame.from_dict(test_folds['val_fold_9'])
test10 = pd.DataFrame.from_dict(test_folds['val_fold_10'])
test11 = pd.DataFrame.from_dict(test_folds['val_fold_11'])
test12 = pd.DataFrame.from_dict(test_folds['val_fold_12'])
test13 = pd.DataFrame.from_dict(test_folds['val_fold_13'])
test14 = pd.DataFrame.from_dict(test_folds['val_fold_14'])
test15 = pd.DataFrame.from_dict(test_folds['val_fold_15'])

# %%
groupDF = [train1,train2,train3,train4,train5,train6,train7,train8,train9,train10,train11,train12,train13,train14,train15,
           test1,test2,test3,test4,test5,test6,test7,test8,test9,test10,test11,test12,test13,test14,test15]
for i in groupDF:
    i.drop(i.columns[[0,21]], axis=1, inplace=True)

# %%
# Find the columns where the distributions are very different
threshold=0.1
diff_data1 = []
for col in tqdm(train1.columns):
    statistic, pvalue = ks_2samp(
        train1[col].values, 
        test1[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data1.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    #else: 
    #    diff_data1.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df1 = pd.DataFrame(diff_data1).sort_values(by='statistic', ascending=False)

diff_df1
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2472.25it/s]
#             feature        p  statistic
# 0  Pancreas_GTExTPM  0.00175       0.16

# %%
threshold=0.1
diff_data2 = []
for col in tqdm(train1.columns):
    statistic, pvalue = ks_2samp(
        train2[col].values, 
        test2[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data2.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data2.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df2 = pd.DataFrame(diff_data2).sort_values(by='statistic', ascending=False)

diff_df2
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2136.79it/s]
#                                         feature                  statistic
# 0                Heart - Left Ventricle_GTExTPM  No significant difference
# 15                            ppiScore_Exomiser  No significant difference
# 27                   SignalValue_H3k4me3_median  No significant difference
# 26                                    CNVs_ExAC  No significant difference
# 25                   SignalValue_H3k4me1_median  No significant difference
# 24                                   RVIS_Score  No significant difference
# 23                                    GDI_Score  No significant difference
# 22                                          SDI  No significant difference
# 21                                     pLI_ExAC  No significant difference
# 20                                       HIPred  No significant difference
# 19  Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 18                     Brain - Amygdala_GTExTPM  No significant difference
# 17                        Adrenal Gland_GTExTPM  No significant difference
# 16                            Pituitary_GTExTPM  No significant difference
# 14                           fishScore_Exomiser  No significant difference
# 1                       Kidney - Cortex_GTExTPM  No significant difference
# 13                          mouseScore_Exomiser  No significant difference
# 12                          humanScore_Exomiser  No significant difference
# 11                          Whole Blood_GTExTPM  No significant difference
# 10                               Testis_GTExTPM  No significant difference
# 9                                Spleen_GTExTPM  No significant difference
# 8      Small Intestine - Terminal Ileum_GTExTPM  No significant difference
# 7   Skin - Not Sun Exposed (Suprapubic)_GTExTPM  No significant difference
# 6                              Pancreas_GTExTPM  No significant difference
# 5                                 Ovary_GTExTPM  No significant difference
# 4                        Nerve - Tibial_GTExTPM  No significant difference
# 3                                  Lung_GTExTPM  No significant difference
# 2                                 Liver_GTExTPM  No significant difference
# 28                                label_encoded  No significant difference

# %%
threshold=0.1
diff_data3 = []
for col in tqdm(train3.columns):
    statistic, pvalue = ks_2samp(
        train3[col].values, 
        test3[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data3.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data3.append({'feature': col,'statistic':'No significant difference'})
    

# Put the differences into a dataframe
diff_df3 = pd.DataFrame(diff_data3).sort_values(by='statistic', ascending=False)

diff_df3
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2096.28it/s]
#                                         feature                  statistic
# 0                Heart - Left Ventricle_GTExTPM  No significant difference
# 15                            ppiScore_Exomiser  No significant difference
# 27                   SignalValue_H3k4me3_median  No significant difference
# 26                                    CNVs_ExAC  No significant difference
# 25                   SignalValue_H3k4me1_median  No significant difference
# 24                                   RVIS_Score  No significant difference
# 23                                    GDI_Score  No significant difference
# 22                                          SDI  No significant difference
# 21                                     pLI_ExAC  No significant difference
# 20                                       HIPred  No significant difference
# 19  Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 18                     Brain - Amygdala_GTExTPM  No significant difference
# 17                        Adrenal Gland_GTExTPM  No significant difference
# 16                            Pituitary_GTExTPM  No significant difference
# 14                           fishScore_Exomiser  No significant difference
# 1                       Kidney - Cortex_GTExTPM  No significant difference
# 13                          mouseScore_Exomiser  No significant difference
# 12                          humanScore_Exomiser  No significant difference
# 11                          Whole Blood_GTExTPM  No significant difference
# 10                               Testis_GTExTPM  No significant difference
# 9                                Spleen_GTExTPM  No significant difference
# 8      Small Intestine - Terminal Ileum_GTExTPM  No significant difference
# 7   Skin - Not Sun Exposed (Suprapubic)_GTExTPM  No significant difference
# 6                              Pancreas_GTExTPM  No significant difference
# 5                                 Ovary_GTExTPM  No significant difference
# 4                        Nerve - Tibial_GTExTPM  No significant difference
# 3                                  Lung_GTExTPM  No significant difference
# 2                                 Liver_GTExTPM  No significant difference
# 28                                label_encoded  No significant difference

# %%
threshold=0.1
diff_data4 = []
nondiff_data4 = []
for col in tqdm(train4.columns):
    statistic, pvalue = ks_2samp(
        train4[col].values, 
        test4[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data4.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data4.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df4 = pd.DataFrame(diff_data4).sort_values(by='statistic', ascending=False)
diff_df4
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2174.89it/s]
#                                         feature                  statistic
# 0                Heart - Left Ventricle_GTExTPM  No significant difference
# 15                            ppiScore_Exomiser  No significant difference
# 27                   SignalValue_H3k4me3_median  No significant difference
# 26                                    CNVs_ExAC  No significant difference
# 25                   SignalValue_H3k4me1_median  No significant difference
# 24                                   RVIS_Score  No significant difference
# 23                                    GDI_Score  No significant difference
# 22                                          SDI  No significant difference
# 21                                     pLI_ExAC  No significant difference
# 20                                       HIPred  No significant difference
# 19  Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 18                     Brain - Amygdala_GTExTPM  No significant difference
# 17                        Adrenal Gland_GTExTPM  No significant difference
# 16                            Pituitary_GTExTPM  No significant difference
# 14                           fishScore_Exomiser  No significant difference
# 1                       Kidney - Cortex_GTExTPM  No significant difference
# 13                          mouseScore_Exomiser  No significant difference
# 12                          humanScore_Exomiser  No significant difference
# 11                          Whole Blood_GTExTPM  No significant difference
# 10                               Testis_GTExTPM  No significant difference
# 9                                Spleen_GTExTPM  No significant difference
# 8      Small Intestine - Terminal Ileum_GTExTPM  No significant difference
# 7   Skin - Not Sun Exposed (Suprapubic)_GTExTPM  No significant difference
# 6                              Pancreas_GTExTPM  No significant difference
# 5                                 Ovary_GTExTPM  No significant difference
# 4                        Nerve - Tibial_GTExTPM  No significant difference
# 3                                  Lung_GTExTPM  No significant difference
# 2                                 Liver_GTExTPM  No significant difference
# 28                                label_encoded  No significant difference

# %%
threshold=0.1
diff_data5 = []
for col in tqdm(train5.columns):
    statistic, pvalue = ks_2samp(
        train5[col].values, 
        test5[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data5.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    #else: 
    #    diff_data5.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df5 = pd.DataFrame(diff_data5).sort_values(by='statistic', ascending=False)

diff_df5
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2771.67it/s]
#   feature        p  statistic
# 0     SDI  0.00714       0.15

# %%
threshold=0.1
diff_data6 = []
for col in tqdm(train5.columns):
    statistic, pvalue = ks_2samp(
        train6[col].values, 
        test6[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data6.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data6.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df6 = pd.DataFrame(diff_data6).sort_values(by='statistic', ascending=False)

diff_df6
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2624.66it/s]
#                                         feature                  statistic
# 0                Heart - Left Ventricle_GTExTPM  No significant difference
# 15                            ppiScore_Exomiser  No significant difference
# 27                   SignalValue_H3k4me3_median  No significant difference
# 26                                    CNVs_ExAC  No significant difference
# 25                   SignalValue_H3k4me1_median  No significant difference
# 24                                   RVIS_Score  No significant difference
# 23                                    GDI_Score  No significant difference
# 22                                          SDI  No significant difference
# 21                                     pLI_ExAC  No significant difference
# 20                                       HIPred  No significant difference
# 19  Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 18                     Brain - Amygdala_GTExTPM  No significant difference
# 17                        Adrenal Gland_GTExTPM  No significant difference
# 16                            Pituitary_GTExTPM  No significant difference
# 14                           fishScore_Exomiser  No significant difference
# 1                       Kidney - Cortex_GTExTPM  No significant difference
# 13                          mouseScore_Exomiser  No significant difference
# 12                          humanScore_Exomiser  No significant difference
# 11                          Whole Blood_GTExTPM  No significant difference
# 10                               Testis_GTExTPM  No significant difference
# 9                                Spleen_GTExTPM  No significant difference
# 8      Small Intestine - Terminal Ileum_GTExTPM  No significant difference
# 7   Skin - Not Sun Exposed (Suprapubic)_GTExTPM  No significant difference
# 6                              Pancreas_GTExTPM  No significant difference
# 5                                 Ovary_GTExTPM  No significant difference
# 4                        Nerve - Tibial_GTExTPM  No significant difference
# 3                                  Lung_GTExTPM  No significant difference
# 2                                 Liver_GTExTPM  No significant difference
# 28                                label_encoded  No significant difference

# %%
threshold=0.1
diff_data7 = []
for col in tqdm(train7.columns):
    statistic, pvalue = ks_2samp(
        train7[col].values, 
        test7[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data7.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data7.append({'feature': col,'statistic':'No significant difference'})
 

diff_df7 = pd.DataFrame(diff_data7).sort_values(by='statistic', ascending=False)

diff_df7
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2078.09it/s]
#                                         feature                  statistic
# 0                Heart - Left Ventricle_GTExTPM  No significant difference
# 15                            ppiScore_Exomiser  No significant difference
# 27                   SignalValue_H3k4me3_median  No significant difference
# 26                                    CNVs_ExAC  No significant difference
# 25                   SignalValue_H3k4me1_median  No significant difference
# 24                                   RVIS_Score  No significant difference
# 23                                    GDI_Score  No significant difference
# 22                                          SDI  No significant difference
# 21                                     pLI_ExAC  No significant difference
# 20                                       HIPred  No significant difference
# 19  Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 18                     Brain - Amygdala_GTExTPM  No significant difference
# 17                        Adrenal Gland_GTExTPM  No significant difference
# 16                            Pituitary_GTExTPM  No significant difference
# 14                           fishScore_Exomiser  No significant difference
# 1                       Kidney - Cortex_GTExTPM  No significant difference
# 13                          mouseScore_Exomiser  No significant difference
# 12                          humanScore_Exomiser  No significant difference
# 11                          Whole Blood_GTExTPM  No significant difference
# 10                               Testis_GTExTPM  No significant difference
# 9                                Spleen_GTExTPM  No significant difference
# 8      Small Intestine - Terminal Ileum_GTExTPM  No significant difference
# 7   Skin - Not Sun Exposed (Suprapubic)_GTExTPM  No significant difference
# 6                              Pancreas_GTExTPM  No significant difference
# 5                                 Ovary_GTExTPM  No significant difference
# 4                        Nerve - Tibial_GTExTPM  No significant difference
# 3                                  Lung_GTExTPM  No significant difference
# 2                                 Liver_GTExTPM  No significant difference
# 28                                label_encoded  No significant difference

# %%
threshold=0.1
diff_data8 = []
for col in tqdm(train3.columns):
    statistic, pvalue = ks_2samp(
        train8[col].values, 
        test8[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data8.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data8.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df8 = pd.DataFrame(diff_data8).sort_values(by='statistic', ascending=False)

diff_df8
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2267.57it/s]
#                                         feature                  statistic
# 0                Heart - Left Ventricle_GTExTPM  No significant difference
# 15                            ppiScore_Exomiser  No significant difference
# 27                   SignalValue_H3k4me3_median  No significant difference
# 26                                    CNVs_ExAC  No significant difference
# 25                   SignalValue_H3k4me1_median  No significant difference
# 24                                   RVIS_Score  No significant difference
# 23                                    GDI_Score  No significant difference
# 22                                          SDI  No significant difference
# 21                                     pLI_ExAC  No significant difference
# 20                                       HIPred  No significant difference
# 19  Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 18                     Brain - Amygdala_GTExTPM  No significant difference
# 17                        Adrenal Gland_GTExTPM  No significant difference
# 16                            Pituitary_GTExTPM  No significant difference
# 14                           fishScore_Exomiser  No significant difference
# 1                       Kidney - Cortex_GTExTPM  No significant difference
# 13                          mouseScore_Exomiser  No significant difference
# 12                          humanScore_Exomiser  No significant difference
# 11                          Whole Blood_GTExTPM  No significant difference
# 10                               Testis_GTExTPM  No significant difference
# 9                                Spleen_GTExTPM  No significant difference
# 8      Small Intestine - Terminal Ileum_GTExTPM  No significant difference
# 7   Skin - Not Sun Exposed (Suprapubic)_GTExTPM  No significant difference
# 6                              Pancreas_GTExTPM  No significant difference
# 5                                 Ovary_GTExTPM  No significant difference
# 4                        Nerve - Tibial_GTExTPM  No significant difference
# 3                                  Lung_GTExTPM  No significant difference
# 2                                 Liver_GTExTPM  No significant difference
# 28                                label_encoded  No significant difference

# %%
threshold=0.1
diff_data9 = []
for col in tqdm(train9.columns):
    statistic, pvalue = ks_2samp(
        train9[col].values, 
        test9[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data9.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data9.append({'feature': col,'statistic':'No significant difference'})


# Put the differences into a dataframe
diff_df9 = pd.DataFrame(diff_data9).sort_values(by='statistic', ascending=False)

diff_df9
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2207.01it/s]
#                                         feature                  statistic
# 0                Heart - Left Ventricle_GTExTPM  No significant difference
# 15                            ppiScore_Exomiser  No significant difference
# 27                   SignalValue_H3k4me3_median  No significant difference
# 26                                    CNVs_ExAC  No significant difference
# 25                   SignalValue_H3k4me1_median  No significant difference
# 24                                   RVIS_Score  No significant difference
# 23                                    GDI_Score  No significant difference
# 22                                          SDI  No significant difference
# 21                                     pLI_ExAC  No significant difference
# 20                                       HIPred  No significant difference
# 19  Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 18                     Brain - Amygdala_GTExTPM  No significant difference
# 17                        Adrenal Gland_GTExTPM  No significant difference
# 16                            Pituitary_GTExTPM  No significant difference
# 14                           fishScore_Exomiser  No significant difference
# 1                       Kidney - Cortex_GTExTPM  No significant difference
# 13                          mouseScore_Exomiser  No significant difference
# 12                          humanScore_Exomiser  No significant difference
# 11                          Whole Blood_GTExTPM  No significant difference
# 10                               Testis_GTExTPM  No significant difference
# 9                                Spleen_GTExTPM  No significant difference
# 8      Small Intestine - Terminal Ileum_GTExTPM  No significant difference
# 7   Skin - Not Sun Exposed (Suprapubic)_GTExTPM  No significant difference
# 6                              Pancreas_GTExTPM  No significant difference
# 5                                 Ovary_GTExTPM  No significant difference
# 4                        Nerve - Tibial_GTExTPM  No significant difference
# 3                                  Lung_GTExTPM  No significant difference
# 2                                 Liver_GTExTPM  No significant difference
# 28                                label_encoded  No significant difference

# %%
threshold=0.1
diff_data10 = []
for col in tqdm(train3.columns):
    statistic, pvalue = ks_2samp(
        train10[col].values, 
        test10[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data10.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data10.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df10 = pd.DataFrame(diff_data10).sort_values(by='statistic', ascending=False)

diff_df10
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2084.54it/s]
#                                         feature                  statistic
# 0                Heart - Left Ventricle_GTExTPM  No significant difference
# 15                            ppiScore_Exomiser  No significant difference
# 27                   SignalValue_H3k4me3_median  No significant difference
# 26                                    CNVs_ExAC  No significant difference
# 25                   SignalValue_H3k4me1_median  No significant difference
# 24                                   RVIS_Score  No significant difference
# 23                                    GDI_Score  No significant difference
# 22                                          SDI  No significant difference
# 21                                     pLI_ExAC  No significant difference
# 20                                       HIPred  No significant difference
# 19  Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 18                     Brain - Amygdala_GTExTPM  No significant difference
# 17                        Adrenal Gland_GTExTPM  No significant difference
# 16                            Pituitary_GTExTPM  No significant difference
# 14                           fishScore_Exomiser  No significant difference
# 1                       Kidney - Cortex_GTExTPM  No significant difference
# 13                          mouseScore_Exomiser  No significant difference
# 12                          humanScore_Exomiser  No significant difference
# 11                          Whole Blood_GTExTPM  No significant difference
# 10                               Testis_GTExTPM  No significant difference
# 9                                Spleen_GTExTPM  No significant difference
# 8      Small Intestine - Terminal Ileum_GTExTPM  No significant difference
# 7   Skin - Not Sun Exposed (Suprapubic)_GTExTPM  No significant difference
# 6                              Pancreas_GTExTPM  No significant difference
# 5                                 Ovary_GTExTPM  No significant difference
# 4                        Nerve - Tibial_GTExTPM  No significant difference
# 3                                  Lung_GTExTPM  No significant difference
# 2                                 Liver_GTExTPM  No significant difference
# 28                                label_encoded  No significant difference

# %%
threshold=0.1
diff_data11 = []
for col in tqdm(train11.columns):
    statistic, pvalue = ks_2samp(
        train11[col].values, 
        test11[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data11.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data11.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df11 = pd.DataFrame(diff_data11).sort_values(by='statistic', ascending=False)

diff_df11
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2102.99it/s]
#                                         feature                  statistic
# 0                Heart - Left Ventricle_GTExTPM  No significant difference
# 15                            ppiScore_Exomiser  No significant difference
# 27                   SignalValue_H3k4me3_median  No significant difference
# 26                                    CNVs_ExAC  No significant difference
# 25                   SignalValue_H3k4me1_median  No significant difference
# 24                                   RVIS_Score  No significant difference
# 23                                    GDI_Score  No significant difference
# 22                                          SDI  No significant difference
# 21                                     pLI_ExAC  No significant difference
# 20                                       HIPred  No significant difference
# 19  Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 18                     Brain - Amygdala_GTExTPM  No significant difference
# 17                        Adrenal Gland_GTExTPM  No significant difference
# 16                            Pituitary_GTExTPM  No significant difference
# 14                           fishScore_Exomiser  No significant difference
# 1                       Kidney - Cortex_GTExTPM  No significant difference
# 13                          mouseScore_Exomiser  No significant difference
# 12                          humanScore_Exomiser  No significant difference
# 11                          Whole Blood_GTExTPM  No significant difference
# 10                               Testis_GTExTPM  No significant difference
# 9                                Spleen_GTExTPM  No significant difference
# 8      Small Intestine - Terminal Ileum_GTExTPM  No significant difference
# 7   Skin - Not Sun Exposed (Suprapubic)_GTExTPM  No significant difference
# 6                              Pancreas_GTExTPM  No significant difference
# 5                                 Ovary_GTExTPM  No significant difference
# 4                        Nerve - Tibial_GTExTPM  No significant difference
# 3                                  Lung_GTExTPM  No significant difference
# 2                                 Liver_GTExTPM  No significant difference
# 28                                label_encoded  No significant difference

# %%
threshold=0.1
diff_data12 = []
for col in tqdm(train3.columns):
    statistic, pvalue = ks_2samp(
        train12[col].values, 
        test12[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data12.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data12.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df12 = pd.DataFrame(diff_data12).sort_values(by='statistic', ascending=False)

diff_df12
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2011.09it/s]
#                                         feature                  statistic
# 0                Heart - Left Ventricle_GTExTPM  No significant difference
# 15                            ppiScore_Exomiser  No significant difference
# 27                   SignalValue_H3k4me3_median  No significant difference
# 26                                    CNVs_ExAC  No significant difference
# 25                   SignalValue_H3k4me1_median  No significant difference
# 24                                   RVIS_Score  No significant difference
# 23                                    GDI_Score  No significant difference
# 22                                          SDI  No significant difference
# 21                                     pLI_ExAC  No significant difference
# 20                                       HIPred  No significant difference
# 19  Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 18                     Brain - Amygdala_GTExTPM  No significant difference
# 17                        Adrenal Gland_GTExTPM  No significant difference
# 16                            Pituitary_GTExTPM  No significant difference
# 14                           fishScore_Exomiser  No significant difference
# 1                       Kidney - Cortex_GTExTPM  No significant difference
# 13                          mouseScore_Exomiser  No significant difference
# 12                          humanScore_Exomiser  No significant difference
# 11                          Whole Blood_GTExTPM  No significant difference
# 10                               Testis_GTExTPM  No significant difference
# 9                                Spleen_GTExTPM  No significant difference
# 8      Small Intestine - Terminal Ileum_GTExTPM  No significant difference
# 7   Skin - Not Sun Exposed (Suprapubic)_GTExTPM  No significant difference
# 6                              Pancreas_GTExTPM  No significant difference
# 5                                 Ovary_GTExTPM  No significant difference
# 4                        Nerve - Tibial_GTExTPM  No significant difference
# 3                                  Lung_GTExTPM  No significant difference
# 2                                 Liver_GTExTPM  No significant difference
# 28                                label_encoded  No significant difference

# %%
threshold=0.1
diff_data13 = []
for col in tqdm(train3.columns):
    statistic, pvalue = ks_2samp(
        train13[col].values, 
        test13[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data13.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data13.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df13 = pd.DataFrame(diff_data13).sort_values(by='statistic', ascending=False)

diff_df13
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2142.63it/s]
#                                         feature                  statistic
# 0                Heart - Left Ventricle_GTExTPM  No significant difference
# 15                            ppiScore_Exomiser  No significant difference
# 27                   SignalValue_H3k4me3_median  No significant difference
# 26                                    CNVs_ExAC  No significant difference
# 25                   SignalValue_H3k4me1_median  No significant difference
# 24                                   RVIS_Score  No significant difference
# 23                                    GDI_Score  No significant difference
# 22                                          SDI  No significant difference
# 21                                     pLI_ExAC  No significant difference
# 20                                       HIPred  No significant difference
# 19  Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 18                     Brain - Amygdala_GTExTPM  No significant difference
# 17                        Adrenal Gland_GTExTPM  No significant difference
# 16                            Pituitary_GTExTPM  No significant difference
# 14                           fishScore_Exomiser  No significant difference
# 1                       Kidney - Cortex_GTExTPM  No significant difference
# 13                          mouseScore_Exomiser  No significant difference
# 12                          humanScore_Exomiser  No significant difference
# 11                          Whole Blood_GTExTPM  No significant difference
# 10                               Testis_GTExTPM  No significant difference
# 9                                Spleen_GTExTPM  No significant difference
# 8      Small Intestine - Terminal Ileum_GTExTPM  No significant difference
# 7   Skin - Not Sun Exposed (Suprapubic)_GTExTPM  No significant difference
# 6                              Pancreas_GTExTPM  No significant difference
# 5                                 Ovary_GTExTPM  No significant difference
# 4                        Nerve - Tibial_GTExTPM  No significant difference
# 3                                  Lung_GTExTPM  No significant difference
# 2                                 Liver_GTExTPM  No significant difference
# 28                                label_encoded  No significant difference

# %%
threshold=0.1
diff_data14 = []
for col in tqdm(train3.columns):
    statistic, pvalue = ks_2samp(
        train14[col].values, 
        test14[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data14.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data14.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df14 = pd.DataFrame(diff_data14).sort_values(by='statistic', ascending=False)

diff_df14
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2135.97it/s]
#                                         feature                  statistic
# 0                Heart - Left Ventricle_GTExTPM  No significant difference
# 15                            ppiScore_Exomiser  No significant difference
# 27                   SignalValue_H3k4me3_median  No significant difference
# 26                                    CNVs_ExAC  No significant difference
# 25                   SignalValue_H3k4me1_median  No significant difference
# 24                                   RVIS_Score  No significant difference
# 23                                    GDI_Score  No significant difference
# 22                                          SDI  No significant difference
# 21                                     pLI_ExAC  No significant difference
# 20                                       HIPred  No significant difference
# 19  Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 18                     Brain - Amygdala_GTExTPM  No significant difference
# 17                        Adrenal Gland_GTExTPM  No significant difference
# 16                            Pituitary_GTExTPM  No significant difference
# 14                           fishScore_Exomiser  No significant difference
# 1                       Kidney - Cortex_GTExTPM  No significant difference
# 13                          mouseScore_Exomiser  No significant difference
# 12                          humanScore_Exomiser  No significant difference
# 11                          Whole Blood_GTExTPM  No significant difference
# 10                               Testis_GTExTPM  No significant difference
# 9                                Spleen_GTExTPM  No significant difference
# 8      Small Intestine - Terminal Ileum_GTExTPM  No significant difference
# 7   Skin - Not Sun Exposed (Suprapubic)_GTExTPM  No significant difference
# 6                              Pancreas_GTExTPM  No significant difference
# 5                                 Ovary_GTExTPM  No significant difference
# 4                        Nerve - Tibial_GTExTPM  No significant difference
# 3                                  Lung_GTExTPM  No significant difference
# 2                                 Liver_GTExTPM  No significant difference
# 28                                label_encoded  No significant difference

# %%
threshold=0.1
diff_data15 = []
for col in tqdm(train3.columns):
    statistic, pvalue = ks_2samp(
        train15[col].values, 
        test15[col].values
    )
    if pvalue <= 0.01 and np.abs(statistic) > threshold:
        diff_data15.append({'feature': col, 'p': np.round(pvalue, 5), 'statistic': np.round(np.abs(statistic), 2)})
    else: 
        diff_data15.append({'feature': col,'statistic':'No significant difference'})

# Put the differences into a dataframe
diff_df15 = pd.DataFrame(diff_data15).sort_values(by='statistic', ascending=False)

diff_df15
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 2253.08it/s]
#                                         feature                  statistic
# 0                Heart - Left Ventricle_GTExTPM  No significant difference
# 15                            ppiScore_Exomiser  No significant difference
# 27                   SignalValue_H3k4me3_median  No significant difference
# 26                                    CNVs_ExAC  No significant difference
# 25                   SignalValue_H3k4me1_median  No significant difference
# 24                                   RVIS_Score  No significant difference
# 23                                    GDI_Score  No significant difference
# 22                                          SDI  No significant difference
# 21                                     pLI_ExAC  No significant difference
# 20                                       HIPred  No significant difference
# 19  Cells - EBV-transformed lymphocytes_GTExTPM  No significant difference
# 18                     Brain - Amygdala_GTExTPM  No significant difference
# 17                        Adrenal Gland_GTExTPM  No significant difference
# 16                            Pituitary_GTExTPM  No significant difference
# 14                           fishScore_Exomiser  No significant difference
# 1                       Kidney - Cortex_GTExTPM  No significant difference
# 13                          mouseScore_Exomiser  No significant difference
# 12                          humanScore_Exomiser  No significant difference
# 11                          Whole Blood_GTExTPM  No significant difference
# 10                               Testis_GTExTPM  No significant difference
# 9                                Spleen_GTExTPM  No significant difference
# 8      Small Intestine - Terminal Ileum_GTExTPM  No significant difference
# 7   Skin - Not Sun Exposed (Suprapubic)_GTExTPM  No significant difference
# 6                              Pancreas_GTExTPM  No significant difference
# 5                                 Ovary_GTExTPM  No significant difference
# 4                        Nerve - Tibial_GTExTPM  No significant difference
# 3                                  Lung_GTExTPM  No significant difference
# 2                                 Liver_GTExTPM  No significant difference
# 28                                label_encoded  No significant difference

# %%
#frames = []
#result = pd.concat(frames)
#result_df = result.drop_duplicates(subset=['feature'], keep='first')
#list(result_df['feature'])
